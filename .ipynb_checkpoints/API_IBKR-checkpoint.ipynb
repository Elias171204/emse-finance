# %% [markdown]
# # Introduction to IBKR API:

# %%
# Here are the imports that we will need throughout the all notebook

import pandas as pd
import numpy as np
import os
import time
import matplotlib.pyplot as plt
import sklearn
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
import threading
from ib_insync import *
import asyncio
import scipy
from ib_insync import IB, Stock, util
from ib_insync import Future
from ib_insync import Stock
from ib_insync import Option

# %%
ib = IB()
util.startLoop()
await ib.connectAsync('127.0.0.1', 7497, clientId=7) # Don't forget to change the client ID
# Out:
# <IB connected to 127.0.0.1:7497 clientId=7>
# Error 200, reqId 9: Aucune d\u00e9finition de titre trouv\u00e9e pour cette requ\u00eate, contract: Future(symbol='FESX', exchange='EUREX', currency='EUR')
# Error 200, reqId 10: Aucune d\u00e9finition de titre trouv\u00e9e pour cette requ\u00eate, contract: Future(symbol='FESX', exchange='EUREX', currency='EUR')
# Error 200, reqId 11: Aucune d\u00e9finition de titre trouv\u00e9e pour cette requ\u00eate, contract: Future(symbol='FESX', exchange='EUREX', currency='EUR')
# Error 200, reqId 22: Aucune d\u00e9finition de titre trouv\u00e9e pour cette requ\u00eate, contract: Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=40.0, right='C', exchange='EUREX', currency='EUR')
# Error 200, reqId 23: Aucune d\u00e9finition de titre trouv\u00e9e pour cette requ\u00eate, contract: Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=40.0, right='C', exchange='EUREX', currency='EUR')

# %% [markdown]
# # Spot OVHLC:

# %%
def ibkr_download(
    ib,
    ticker: str,
    start: str,
    end: str,
    interval: str = "15 mins",
    exchange: str = "SMART",
    currency: str = "EUR",
    primaryExchange: str = "SBF",
    chunk: str = "1 Y",
    useRTH: bool = False,
    sleep_s: float = 0.6
) -> pd.DataFrame:
    """
    Simple wrapper style yfinance, mais IBKR.
    - ib : instance IB déjà connectée
    - start/end : 'YYYY-MM-DD'
    - interval : ex '15 mins'
    """

    def to_naive(ts: pd.Timestamp) -> pd.Timestamp:
        ts = pd.to_datetime(ts)
        if getattr(ts, "tzinfo", None) is not None:
            ts = ts.tz_localize(None)
        return ts

    start_dt = to_naive(start)
    end_dt   = to_naive(end)

    contract = Stock(ticker, exchange, currency, primaryExchange=primaryExchange)
    ib.qualifyContracts(contract)

    dfs = []
    current_end = end_dt

    while current_end > start_dt:
        bars = ib.reqHistoricalData(
            contract,
            endDateTime=current_end.strftime("%Y%m%d %H:%M:%S"),
            durationStr=chunk,            # "1 Y" (si pacing: "6 M")
            barSizeSetting=interval,      # "15 mins"
            whatToShow="TRADES",
            useRTH=useRTH,
            formatDate=1
        )

        if not bars:
            break

        df = util.df(bars).rename(columns={"date": "Datetime"})
        df["Datetime"] = pd.to_datetime(df["Datetime"])

        # IMPORTANT: rendre tz-naive si IB renvoie une timezone
        if hasattr(df["Datetime"].dt, "tz") and df["Datetime"].dt.tz is not None:
            df["Datetime"] = df["Datetime"].dt.tz_localize(None)

        dfs.append(df)

        current_end = df["Datetime"].min()
        ib.sleep(sleep_s)

    if not dfs:
        return pd.DataFrame()

    out = (pd.concat(dfs, ignore_index=True)
             .drop_duplicates(subset=["Datetime"])
             .sort_values("Datetime")
             .reset_index(drop=True))

    return out[(out["Datetime"] >= start_dt) & (out["Datetime"] <= end_dt)]

# %%
df = ibkr_download(
    ib,
    ticker="TTE",
    start="2020-01-01",
    end="2025-01-01",
    interval="1 day"
)


# 1 secs, 5 secs, 10 secs, 15 secs, 30 secs, 1 min, 2 mins, 3 mins, 4 mins, 5 mins, 10 mins, 15 mins, 20 mins, 30 mins, 1 hour, 2 hours, 3 hours, 4 hours, 8 hours, 1 day, 1W, 1M sont les durées acceptées par IBKR

# %%
df
# Out:
#        Datetime   open   high     low   close      volume  average  barCount
# 2    2020-01-02  49.48  50.23  49.214  49.816   5891394.0  49.8284     30157
# 3    2020-01-03  50.00  50.66  49.784  50.380   7078714.0  50.2772     29485
# 4    2020-01-06  49.97  50.98  49.450  50.440  10330669.0  50.5354     44417
# 5    2020-01-07  50.59  50.67  50.110  50.110   7292067.0  50.3072     32275
# 6    2020-01-08  50.32  50.75  49.734  50.240   7435619.0  50.2832     35333
# ...         ...    ...    ...     ...     ...         ...      ...       ...
# 1279 2024-12-23  52.36  54.30  51.595  51.850   4168490.0  51.7730     30600
# 1280 2024-12-24  52.00  54.70  51.930  52.010   1817887.0  52.1690      9161
# 1281 2024-12-27  51.96  55.00  51.810  52.750   5002837.0  52.4320     27695
# 1282 2024-12-30  52.69  55.20  52.290  52.600   4331003.0  52.6055     23060
# 1283 2024-12-31  52.62  55.60  50.600  53.370   2176151.0  53.1475     11137
#
# [1282 rows x 8 columns]

# %%
plt.plot(df["Datetime"], df["close"], label="TTE")
plt.legend()
plt.title("cours de TTE")
plt.xlabel("année")
plt.ylabel("Valeur")
plt.show()

# %% [markdown]
# # Futures:

# %%
CANDIDATES = [

    ("CL",   "NYMEX",  "USD"),   # WTI Crude Oil
    ("GC",   "COMEX",  "USD"),   # Gold
    ("6E",   "CME",    "USD"),   # EUR/USD future
    ("FDAX", "EUREX",  "EUR"),   # DAX future
    ("FESX", "EUREX",  "EUR"),   # Euro Stoxx 50 future
]

async def find_any_future_contracts(ib, n_show=10):
    for sym, ex, ccy in CANDIDATES:
        c = Future(sym, exchange=ex, currency=ccy)
        details = await ib.reqContractDetailsAsync(c)

        if details and len(details) > 0:
            print(f"OK -> {sym} @ {ex} ({ccy}) | Nb contrats: {len(details)}")
            for d in details[:n_show]:
                cd = d.contract
                print(cd.localSymbol, cd.lastTradeDateOrContractMonth, cd.multiplier)
            return details  # renvoie les détails du premier marché qui marche

        print(f"KO -> {sym} @ {ex} ({ccy}) | Nb contrats: 0")

    return []

details = await find_any_future_contracts(ib, n_show=10)
# Out:
# OK -> CL @ NYMEX (USD) | Nb contrats: 133
# CLG6 20260120 1000
# CLM6 20260519 1000
# CLZ6 20261120 1000
# CLF7 20261221 1000
# CLG7 20270120 1000
# CLH6 20260220 1000
# CLJ6 20260320 1000
# CLK6 20260421 1000
# CLN6 20260622 1000
# CLQ6 20260721 1000

# %%
details_sorted = sorted(details, key=lambda d: d.contract.lastTradeDateOrContractMonth)

front = details_sorted[0].contract
print("Front month:", front.localSymbol, front.lastTradeDateOrContractMonth, "mult:", front.multiplier)

await ib.qualifyContractsAsync(front)
# Out:
# Front month: CLG6 20260120 mult: 1000
# [Contract(secType='FUT', conId=304037410, symbol='CL', lastTradeDateOrContractMonth='20260120', multiplier='1000', exchange='NYMEX', currency='USD', localSymbol='CLG6', tradingClass='CL')]

# %%
bars = await ib.reqHistoricalDataAsync(
    front,
    endDateTime="",
    durationStr="1 Y",
    barSizeSetting="1 day",
    whatToShow="TRADES",
    useRTH=False,
    formatDate=1
)

df_es = util.df(bars).rename(columns={"date": "Datetime"})
df_es["Datetime"] = pd.to_datetime(df_es["Datetime"])
df_es.head()
# Out:
#     Datetime   open   high    low  close  volume  average  barCount
# 0 2024-12-27  66.71  66.71  66.71  66.71     0.0   66.710         0
# 1 2024-12-30  67.09  67.09  67.02  67.02     2.0   67.090         2
# 2 2024-12-31  67.60  67.60  67.60  67.60     0.0   67.600         0
# 3 2025-01-02  68.00  68.73  68.00  68.30    52.0   68.268        41
# 4 2025-01-03  68.76  68.76  68.69  68.69    25.0   68.750        17

# %%
plt.plot(df_es["Datetime"], df_es["close"], label=front.localSymbol)
plt.legend()
plt.title("ES Future (front month) - Close")
plt.show()

# %%
async def ibkr_list_futures_expiries(
    ib,
    root: str,
    exchange: str,
    currency: str,
    n: int | None = None
) -> pd.DataFrame:
    """
    Retourne toutes les échéances futures à venir pour un sous-jacent future (root symbol).
    Exemple: root="ES", exchange="CME", currency="USD".
    
    - n: optionnel, limite le nombre d'échéances renvoyées (après tri).
    """

    c = Future(root, exchange=exchange, currency=currency)
    details = await ib.reqContractDetailsAsync(c)

    rows = []
    for d in details:
        cd = d.contract
        rows.append({
            "root": root,
            "exchange": exchange,
            "currency": currency,
            "localSymbol": cd.localSymbol,
            "lastTradeDateOrContractMonth": cd.lastTradeDateOrContractMonth,
            "multiplier": cd.multiplier,
            "conId": cd.conId
        })

    df = pd.DataFrame(rows)
    if df.empty:
        return df

    s = df["lastTradeDateOrContractMonth"].astype(str)
    fmt = s.str.len().map({6: "%Y%m", 8: "%Y%m%d"}).fillna("%Y%m%d")

    parsed = []
    for val, f in zip(s, fmt):
        parsed.append(pd.to_datetime(val, format=f, errors="coerce"))
    df["expiry"] = parsed


    now = pd.Timestamp.utcnow().tz_localize(None)
    df = df[df["expiry"].notna() & (df["expiry"] >= now)].copy()

    df = df.sort_values("expiry").reset_index(drop=True)
    if n is not None:
        df = df.head(n).reset_index(drop=True)

    return df

# %%
df_exp = await ibkr_list_futures_expiries(
    ib,
    root="ES",
    exchange="CME",
    currency="USD"
)

df_exp
# Out:
#    root exchange currency localSymbol lastTradeDateOrContractMonth multiplier  \
# 0    ES      CME      USD        ESH6                     20260320         50
# 1    ES      CME      USD        ESM6                     20260618         50
# 2    ES      CME      USD        ESU6                     20260918         50
# 3    ES      CME      USD        ESZ6                     20261218         50
# 4    ES      CME      USD        ESH7                     20270319         50
# 5    ES      CME      USD        ESM7                     20270617         50
# 6    ES      CME      USD        ESU7                     20270917         50
# 7    ES      CME      USD        ESZ7                     20271217         50
# 8    ES      CME      USD        ESH8                     20280317         50
# 9    ES      CME      USD        ESM8                     20280616         50
# 10   ES      CME      USD        ESU8                     20280915         50
# 11   ES      CME      USD        ESZ8                     20281215         50
# 12   ES      CME      USD        ESH9                     20290316         50
# 13   ES      CME      USD        ESM9                     20290615         50
# 14   ES      CME      USD        ESU9                     20290921         50
# 15   ES      CME      USD        ESZ9                     20291221         50
# 16   ES      CME      USD        ESH0                     20300315         50
# 17   ES      CME      USD        ESM0                     20300621         50
# 18   ES      CME      USD        ESU0                     20300920         50
# 19   ES      CME      USD        ESZ0                     20301220         50
# 20   ES      CME      USD        ESH1                     20310321         50
#
#         conId     expiry
# 0   649180695 2026-03-20
# 1   649180678 2026-06-18
# 2   649180671 2026-09-18
# 3   515416632 2026-12-18
# 4   649180684 2027-03-19
# 5   649180661 2027-06-17
# 6   649180681 2027-09-17
# 7   586139767 2027-12-17
# 8   649180666 2028-03-17
# 9   649180690 2028-06-16
# 10  649180675 2028-09-15
# 11  654503299 2028-12-15
# 12  672387437 2029-03-16
# 13  691171642 2029-06-15
# 14  711280049 2029-09-21
# 15  730283071 2029-12-21
# 16  750150169 2030-03-15
# 17  770561177 2030-06-21
# 18  793356200 2030-09-20
# 19  815824241 2030-12-20
# 20  840227374 2031-03-21

# %%
contract = Stock("TTE", "SMART", "EUR", primaryExchange="SBF")
await ib.qualifyContractsAsync(contract)

params = await ib.reqSecDefOptParamsAsync(
    contract.symbol,
    "",
    contract.secType,
    contract.conId
)

params
# Out:
# [OptionChain(exchange='EUREX', underlyingConId='29612193', tradingClass='TOTB', multiplier='100', expirations=['20260102', '20260109', '20260116', '20260123', '20260130', '20260220', '20260320', '20260619', '20260918', '20261218', '20270618', '20271217', '20280616', '20281215', '20291221', '20301220'], strikes=[0.01, 12.0, 14.0, 16.0, 18.0, 20.0, 22.0, 23.0, 24.0, 25.0, 26.0, 28.0, 30.0, 32.0, 34.0, 36.0, 38.0, 40.0, 42.0, 43.5, 44.0, 44.5, 45.0, 45.5, 46.0, 46.5, 47.0, 47.5, 48.0, 48.5, 49.0, 49.5, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 70.0, 72.0, 76.0, 80.0, 84.0, 88.0, 92.0, 96.0, 100.0, 120.0, 140.0]),
#  OptionChain(exchange='MONEP', underlyingConId='29612193', tradingClass='TO9C', multiplier='100', expirations=['20260116', '20260220', '20260320', '20260619', '20260918', '20261218', '20270618', '20271217'], strikes=[30.0, 40.0, 45.0, 48.0, 50.0, 52.0, 54.0, 55.0, 56.0, 58.0, 60.0, 80.0]),
#  OptionChain(exchange='MONEP', underlyingConId='29612193', tradingClass='2TO', multiplier='100', expirations=['20260109'], strikes=[28.0, 30.0, 35.0, 38.0, 40.0, 42.0, 44.0, 46.0, 48.0, 49.0, 50.0, 51.0, 52.0, 52.5, 53.0, 53.5, 54.0, 54.5, 55.0, 55.5, 56.0, 56.5, 57.0, 57.5, 58.0, 59.0, 60.0, 62.0, 64.0, 68.0, 72.0, 76.0]),
#  OptionChain(exchange='MONEP', underlyingConId='29612193', tradingClass='1TO', multiplier='100', expirations=['20260102'], strikes=[28.0, 30.0, 35.0, 38.0, 40.0, 42.0, 44.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 52.5, 53.0, 53.5, 54.0, 54.5, 55.0, 55.5, 56.0, 56.5, 57.0, 57.5, 58.0, 58.5, 59.0, 60.0, 62.0, 64.0, 68.0, 72.0, 76.0]),
#  OptionChain(exchange='EUREX', underlyingConId='29612193', tradingClass='TOTB.1', multiplier='102', expirations=['20261218'], strikes=[31.46, 35.39, 43.25, 47.18, 55.05]),
#  OptionChain(exchange='MONEP', underlyingConId='29612193', tradingClass='TO1', multiplier='100', expirations=['20260116', '20260220', '20260320', '20260619', '20260918', '20270618', '20271217', '20280616', '20281215', '20291221', '20301220'], strikes=[18.0, 20.0, 22.0, 24.0, 25.0, 26.0, 28.0, 30.0, 35.0, 38.0, 40.0, 42.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 62.0, 64.0, 65.0, 66.0, 68.0, 70.0, 72.0, 75.0, 76.0, 80.0, 84.0, 90.0, 100.0, 120.0]),
#  OptionChain(exchange='CEDX', underlyingConId='29612193', tradingClass='TTEO', multiplier='100', expirations=['20260116', '20260220', '20260320', '20260619', '20260918', '20261218', '20270618', '20271217'], strikes=[13.0, 15.0, 16.0, 18.0, 20.0, 25.0, 30.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 49.5, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 68.0, 70.0, 72.0, 75.0, 80.0, 85.0, 90.0, 95.0, 100.0, 120.0, 140.0, 160.0, 180.0]),
#  OptionChain(exchange='MONEP', underlyingConId='29612193', tradingClass='TO1', multiplier='102', expirations=['20261218'], strikes=[24.0, 25.0, 26.0, 28.0, 29.49, 35.0, 39.32, 44.23, 46.0, 48.0, 49.15, 50.0, 52.0, 54.06, 56.0, 58.0, 58.98, 60.0, 64.0, 70.0, 78.64, 90.0, 98.3]),
#  OptionChain(exchange='MONEP', underlyingConId='29612193', tradingClass='TO4', multiplier='100', expirations=['20260116', '20260220', '20260320', '20260619', '20260918', '20261218', '20270618', '20271217'], strikes=[18.0, 20.0, 22.0, 24.0, 25.0, 26.0, 28.0, 30.0, 35.0, 38.0, 40.0, 42.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 62.0, 64.0, 65.0, 68.0, 70.0, 72.0, 75.0, 76.0, 80.0, 84.0, 90.0, 100.0])]

# %%
p = params[0]                     # souvent un seul élément
expiry = sorted(p.expirations)[0] # prochaine échéance
strikes = sorted(p.strikes)

rows = []
for k in strikes:
    for right in ["C", "P"]:
        opt = Option(
            symbol=contract.symbol,
            lastTradeDateOrContractMonth=expiry,
            strike=k,
            right=right,
            exchange=p.exchange,
            currency=contract.currency
        )
        rows.append(opt)

len(rows)
# Out:
# 124

# %%
rows
# Out:
# [Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=0.01, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=0.01, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=12.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=12.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=14.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=14.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=16.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=16.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=18.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=18.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=20.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=20.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=22.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=22.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=23.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=23.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=24.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=24.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=25.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=25.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=26.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=26.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=28.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=28.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=30.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=30.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=32.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=32.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=34.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=34.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=36.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=36.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=38.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=38.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=40.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=40.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=42.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=42.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=43.5, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=43.5, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=44.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=44.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=44.5, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=44.5, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=45.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=45.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=45.5, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=45.5, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=46.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=46.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=46.5, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=46.5, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=47.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=47.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=47.5, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=47.5, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=48.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=48.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=48.5, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=48.5, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=49.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=49.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=49.5, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=49.5, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=50.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=50.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=51.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=51.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=52.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=52.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=53.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=53.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=54.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=54.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=55.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=55.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=56.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=56.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=57.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=57.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=58.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=58.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=59.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=59.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=60.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=60.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=61.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=61.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=62.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=62.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=63.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=63.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=64.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=64.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=65.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=65.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=66.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=66.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=67.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=67.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=68.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=68.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=70.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=70.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=72.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=72.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=76.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=76.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=80.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=80.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=84.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=84.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=88.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=88.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=92.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=92.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=96.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=96.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=100.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=100.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=120.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=120.0, right='P', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=140.0, right='C', exchange='EUREX', currency='EUR'),
#  Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=140.0, right='P', exchange='EUREX', currency='EUR')]

# %%
import pandas as pd
from ib_insync import Option, util

async def ibkr_option_history(
    ib,
    symbol: str,
    expiry: str,          # ex: "20260102"
    strike: float,
    right: str,           # "C" ou "P"
    exchange: str = "EUREX",
    currency: str = "EUR",
    duration: str = "1 Y",
    barSize: str = "1 day",
    useRTH: bool = False
) -> pd.DataFrame:
    """
    Télécharge l'historique de prix d'une option IBKR (daily par défaut).
    """

    opt = Option(
        symbol=symbol,
        lastTradeDateOrContractMonth=expiry,
        strike=strike,
        right=right,
        exchange=exchange,
        currency=currency
    )

    await ib.qualifyContractsAsync(opt)

    bars = await ib.reqHistoricalDataAsync(
        opt,
        endDateTime="",
        durationStr=duration,
        barSizeSetting=barSize,
        whatToShow="TRADES",
        useRTH=useRTH,
        formatDate=1
    )

    if not bars:
        return pd.DataFrame()

    df = util.df(bars).rename(columns={"date": "Datetime"})
    df["Datetime"] = pd.to_datetime(df["Datetime"])

    # Ajout métadonnées option
    df["symbol"] = symbol
    df["expiry"] = expiry
    df["strike"] = strike
    df["right"] = right

    return df

# %%
df_opt_hist = await ibkr_option_history(
    ib,
    symbol="TTE",
    expiry="20260102",
    strike=40.0,
    right="C",
    exchange="EUREX",
    currency="EUR",
    duration="1 Y"
)

df_opt_hist.head()
# Out:
# Unknown contract: Option(symbol='TTE', lastTradeDateOrContractMonth='20260102', strike=40.0, right='C', exchange='EUREX', currency='EUR')
# Empty DataFrame
# Columns: []
# Index: []

# %%
import matplotlib.pyplot as plt

plt.plot(df_opt_hist["Datetime"], df_opt_hist["close"])
plt.title("TTE Call 40€ – historique")
plt.xlabel("Date")
plt.ylabel("Prix option")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.plot(df_opt_hist["Datetime"], df_opt_hist["close"])
#       4 plt.title("TTE Call 40€ – historique")
#       5 plt.xlabel("Date")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Datetime'
