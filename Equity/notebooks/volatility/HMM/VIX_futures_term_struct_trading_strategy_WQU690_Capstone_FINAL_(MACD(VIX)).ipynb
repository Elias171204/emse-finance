# %% [markdown]
# <a href="https://colab.research.google.com/github/ayoubbensakhria/wqu690/blob/master/VIX_futures_term_struct_trading_strategy_WQU690_Capstone_FINAL_(MACD(VIX)).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Strategy Overview
# We will use VIX futures term-structure historical data (from 1/3/2016 to 8/4/2022), SPX/IXIC convergence/divergence to predict next IXIC movement using Ensemble ML model.
#
# ## Features (X):
# - 'vix_macd': VIX Spot MACD at day d (current value)
# - 'vix_signal': VIX MACD Signal value at day d
# - 'contango_m1': % Contango at Month 1 from day d
# - 'contango_m2': % Contango at Month 2 from day d
# - 'contango_m3': % Contango at Month 3 from day d
# - 'spx_macd':  SPX MACD value at day d
# - 'spx_signal': SPX MACD Signal value at day d
# - 'ixic_macd': IXIC MACD value at day d
# - 'ixic_signal': IXIC MACD Signal value at day d
#
# ## Labels (Signals) (y)
# - Target values could be either -1(short) 1(long) or 0(no trade).
# - Refer to section 3 'Compute IXIC trading entry positions (Labels)' to learn how were labels generated.
#
# ### Default MACD Settings
# The typical MACD default settings are (12,26, 9) and refers to the following:
# - (12) – The 12 period exponentially weighted average (EMA) or 'fast line'
# - (26) – The 26 period EMA or 'slow line'
# - (9) – The 9 period EMA of the MACD line, known as the 'signal line'

# %% [markdown]
# # 2. Install and import the required libraries

# %%
import warnings
warnings.filterwarnings('ignore')
# Yahoo finance data library
# !pip install yfinance
# Technical indicators library
# !pip install talib-binary
# Backtesting
# !pip install backtrader
# Pyfolio
# !pip install pyfolio

# %%
import math
import numpy as np
import pandas as pd
import yfinance as yf
import talib as tb
import seaborn as sns
from datetime import date, timedelta, datetime
from dateutil import parser
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import export_text
from sklearn import tree, datasets
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, classification_report, accuracy_score, confusion_matrix
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (24, 12)
plt.style.use('fivethirtyeight')

# %% [markdown]
# # 3. Download Data
# ## 3.1. VIX Futures Term Structure Historical Data

# %%
# Dates Setup
start_date = date(2016, 3, 1)
end_date = date(2025, 4, 8)

# %% [markdown]
# To calculate the current level of contango we use the following formula:
#
# \begin{equation}
# \mathrm{Ct}_{\mathrm{M}_{\mathrm{i}}, \mathrm{M}_{\mathrm{i}+1}}=\frac{\left(\mathrm{FVIX}_{\mathrm{M}_{\mathrm{i}+1}}-\mathrm{FVIX}_{\mathrm{M}_{\mathrm{i}}}\right) \cdot 100}{\mathrm{FVIX}_{\mathrm{M}_{\mathrm{i}}}}
# \end{equation}
#
# Where:
#
# - $\mathrm{Ct}_{\mathrm{M}_{\mathrm{j}}, \mathrm{M}_{\mathrm{i}+1}}$ is % Contango between month $\mathrm{M}_{\mathrm{i}+1}$ and month $\mathrm{M}_{\mathrm{i}}$ VIX Futures.
# - $\mathrm{FVIX}_{\mathrm{M}_{\mathrm{i}+1}}$ and FVIX $\mathrm{M}_{\mathrm{i}}$ are VIX future values at month $\mathrm{M}_{\mathrm{i}+1}$ and $\mathrm{M}_{\mathrm{i}}$ respectively.

# %%
# Get VIX Futures Term Structure Historical Data
vix_futures_csv = 'https://raw.githubusercontent.com/ayoubbensakhria/wqu690/master/data/vix_futures.csv'
df = pd.read_csv(vix_futures_csv, parse_dates=True)
# reverse df
df = df[::-1]
# set df index
df.index = pd.to_datetime(df['Date']).dt.date
# Drop unwanted columns for the current Experiment
columns_drop = ['Date', 'VXX', 'M1 Weight', 'M2 Weight', 'Weighted M1 M2', 'HV5', 'HV10', 'HV20', 'HV30', 'HV60', 'VVIX', 'VXX Bias', 'VRP', 'VIX GEX']
df.drop(columns_drop, axis=1, inplace=True)
# rename VIX3M
df.rename(columns={"VIX3M": "M3"}, inplace=True)
# Get data between start & end dates
mask = (df.index >= start_date) & (df.index< end_date)
df = df[mask]
# Compute Contango values
df['contango_m1'] = (df['M1'] - df['VIX'])*100/df['VIX']
df['contango_m2'] = (df['M2'] - df['M1'])*100/df['M1']
df['contango_m3'] = (df['M3'] - df['M2'])*100/df['M2']
df.head()
# Out:
#               VIX     M1     M2     M3      SPX  contango_m1  contango_m2  \
# Date
# 2016-03-01  17.70  19.40  20.30  20.28  1978.35     9.604520     4.639175
# 2016-03-02  17.09  19.30  20.25  19.92  1986.45    12.931539     4.922280
# 2016-03-03  16.70  18.35  19.50  19.49  1993.40     9.880240     6.267030
# 2016-03-04  16.86  18.95  20.00  19.63  1999.99    12.396204     5.540897
# 2016-03-07  17.35  18.60  19.80  19.90  2001.76     7.204611     6.451613
#
#             contango_m3
# Date
# 2016-03-01    -0.098522
# 2016-03-02    -1.629630
# 2016-03-03    -0.051282
# 2016-03-04    -1.850000
# 2016-03-07     0.505051

# %% [markdown]
# ## 3.2. Download IXIC Historical Data and Join Dataframes

# %%
ixic = yf.download(tickers='^IXIC', start=start_date, end=end_date, interval="1d")
ixic.rename(columns={"Close": "IXIC"}, inplace=True)
ixic.columns = ixic.columns.droplevel(1)
# Out:
# /var/folders/jz/kmcv6z957nb55q23tfvb3kd40000gn/T/ipykernel_30780/3617049852.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ixic = yf.download(tickers='^IXIC', start=start_date, end=end_date, interval="1d")
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # 4. Compute Moving average convergence divergence (MACD) for VIX, SPX and IXIC

# %% [markdown]
# MACD, short for moving average convergence/divergence, is a trading indicator used in technical analysis of stock prices.
#
# MACD tells us about the convergence and divergence of the two moving averages. Convergence occurs when the moving averages move towards each other. Divergence occurs when the moving averages move away from each other.

# %%
df['vix_macd'], df['vix_signal'], df['vix_hist'] = tb.MACDFIX(df['VIX'])
df['spx_macd'], df['spx_signal'], df['spx_hist'] = tb.MACDFIX(df['SPX'])
df['ixic_macd'], df['ixic_signal'], df['ixic_hist'] = tb.MACDFIX(df['IXIC'])
df = df.dropna()
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IXIC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 3
#       1 df['vix_macd'], df['vix_signal'], df['vix_hist'] = tb.MACDFIX(df['VIX'])
#       2 df['spx_macd'], df['spx_signal'], df['spx_hist'] = tb.MACDFIX(df['SPX'])
# ----> 3 df['ixic_macd'], df['ixic_signal'], df['ixic_hist'] = tb.MACDFIX(df['IXIC'])
#       4 df = df.dropna()
#       5 df.head()
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'IXIC'

# %% [markdown]
# ## 4.1. Plot data

# %%
# Info: (x1, y1), (x2, y2)
# x1: number of rows, y1: number of columns 
# x2: row number, y2: column number
# documentation -> https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.subplot2grid.html
# Axe VIX with M1, M2, M3 maturities
plt.figure(figsize=(16,24))
vix_values = plt.subplot2grid((4, 1), (0,0),  colspan = 1, rowspan = 2)
vix_values.plot(df['VIX'], color = '#E74C3C', linewidth = 1,  label = 'VIX Current')
vix_values.plot(df['M1'], color = '#9B59B6', linewidth = 1, label = 'VIX - M1')
vix_values.plot(df['M2'], color = '#2980B9', linewidth = 1, label = 'VIX - M2')
vix_values.plot(df['M3'], color = '#2ECC71', linewidth = 1,  label = 'VIX - M3')
plt.legend(loc = 'upper left')
# Axe prices: SPX and IXIC Close Prices
axe_prices = vix_values.twinx()
axe_prices.plot(df['SPX'], color = 'red', linewidth = 1.5, label = 'SPX')
axe_prices.plot(df['IXIC'], color = 'blue', linewidth = 1.5, label = 'IXIC')
# add titles to subplots
axe_prices.set_title('VIX futures term sructure historical data | SPX and IXIC Adj Close Values')
# set legend position
plt.legend(loc = 'upper right')
# Plot SPX and IXIC MACD
axe_spx_macd = plt.subplot2grid((4, 1), (2,0),  colspan = 1)
axe_spx_macd.plot(df['spx_macd'], color = '#E74C3C', linewidth = 1.5, label = 'SPX MACD')
axe_spx_macd.plot(df['spx_signal'], color = '#9B59B6', linewidth = 1.5, label = 'SPX SIGNAL')
plt.legend(loc = 'lower left')
axe_ixic_macd = axe_spx_macd.twinx()
axe_ixic_macd.plot(df['ixic_macd'], color = '#2980B9', linewidth = 1.5, label = 'IXIC MACD')
axe_ixic_macd.plot(df['ixic_signal'], color = '#2ECC71', linewidth = 1.5, label = 'IXIC SIGNAL')
axe_ixic_macd.set_title('MACD signals for SPX and IXIC')
plt.legend(loc = 'lower right')
# Plot VIX MACD
axe_vix_macd = plt.subplot2grid((4, 1), (3,0),  colspan = 1)
axe_vix_macd.plot(df['vix_macd'], color = '#E74C3C', linewidth = 1.5, label = 'VIX MACD')
axe_vix_macd.plot(df['vix_signal'], color = '#9B59B6', linewidth = 1.5, label = 'VIX SIGNAL')
axe_vix_macd.set_title('MACD signals for VIX')
plt.legend(loc = 'lower left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IXIC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 16
#      14 axe_prices = vix_values.twinx()
#      15 axe_prices.plot(df['SPX'], color = 'red', linewidth = 1.5, label = 'SPX')
# ---> 16 axe_prices.plot(df['IXIC'], color = 'blue', linewidth = 1.5, label = 'IXIC')
#      17 # add titles to subplots
#      18 axe_prices.set_title('VIX futures term sructure historical data | SPX and IXIC Adj Close Values')
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'IXIC'

# %% [markdown]
# # 5. Compute IXIC trading entry positions (Labels)
#
# We compute IXIC entry positions on each point based on the next $l$ historical prices, determined risk:reward ratio, and our profit target.
#
#
# Entry positions (signals) can have one of the following values: -1 (Sell), 1 (Buy), 0 (No Trade). These values will be used as target values to train our model.
#
# To compute signal values from the next l prices we use the following formula:
#
# \begin{equation}
# \mathrm{E}_{\mathrm{t}, 1}=\operatorname{sgn}\left(\log \left(\left|\frac{\frac{\max _{\mathrm{t} \leq i \leq t+l} p_{i}-p_{t}}{p_{t}}}{\frac{\min _{t \leq i \leq t+l} p_{i}-p_{t}}{p_{t}}}\right|\right)\right)
# \end{equation}
#
# Where $\mathrm{E}_{\mathrm{t}, 1}$ is the trading signal at $t$ computed using the next $l$ values.
#
# sgn is defined as follows:
#
# \begin{equation}
# \operatorname{sgn}: \mathbb{R} \rightarrow\{-1,0,1\}
# \end{equation}
#
# \begin{equation}
# x \mapsto \operatorname{sgn}(x)=\left\{\begin{array}{cc}
# -1 & \text { if } x \leq \mathrm{T} \text { and } \frac{\max _{\mathrm{t} \leq i \leq t+l} p_{i}-p_{t}}{p_{t}}<\mathrm{s} \\
# 1 & \text { if } x \geq \mathrm{T} \text { and } \frac{\min _{t \leq i \leq t+l} p_{i}-p_{t}}{p_{t}}>-\mathrm{s} \\
# 0 & \text { Otherwise }
# \end{array}\right.
# \end{equation}
# - $\max _{t \leq i \leq t+l} p_{i}:$ the maximum price value of the vector containing the next $l$ historical prices including the current price.
# - $\min _{t \leq i \leq t+l} p_{i}:$ the minimum price value of the vector containing the next $l$ historical prices including the current price.
# - $T$ : is the Log of the targeted returns (Max/Min) ratio.
# - $p_{t}$ : is the price at time $\mathrm{t}$ (the current price).
# - $\mathrm{s}$ is the rolling Log returns standard deviation: $s=\sqrt{\frac{1}{l-t} \sum_{i=t}^{l}\left(x_{i}-\bar{x}\right)^{2}}$

# %% [markdown]
# ## 5.1. Implement Signal Function

# %% [markdown]
# ###5.1.1. Compute Risk

# %%
# Standard Deviation 
df['Change'] = (df['IXIC']-df['IXIC'].shift(-1))/df['IXIC'].shift(-1)
# compute the risk (std) and the target return
risk = df['Change'].std(skipna=True)
df.drop('Change', axis = 1, inplace=True)
# Define reward/risk coeff
reward_risk_coeff = 1.5

# %%
def sign (df, lags):  #<- lags = historical prices ahead of the current position
  # calculte rolling min and max prices (after the possible entrypoints)
  next_highest_price = df['IXIC'].rolling(lags).max().shift(-lags)
  next_lowest_price = df['IXIC'].rolling(lags).min().shift(-lags)
  # Filter entrypoints before building the model
  df['rolling_max_return'] = ((next_highest_price - df['IXIC']) / df['IXIC'])
  df['rolling_min_return'] = ((next_lowest_price - df['IXIC']) / df['IXIC'])
  #Compute E(t,l) = df['ep']
  df['ep'] = np.log(abs(df['rolling_max_return']/df['rolling_min_return']))
  # drop the last (lags) rows
  df = df[lags:]
  # generate signals for the training dataset
  # signal is +1 if the max price is above the target rate and the min price is above the risk 
  df['tsignal'] = df.apply(
      lambda row: 1 
      if (
          row['ep'] > math.log(reward_risk_coeff) 
          and row['rolling_min_return'] > -risk
          ) 
      else 0, axis =1)
  
  df['atsignal'] = df.apply(
      lambda row: -1 
      if (
          row['ep'] <= -math.log(reward_risk_coeff) 
          and row['rolling_max_return'] < risk
          ) 
      else 0, axis =1)
  
  # Merge sell signals and drop atsignals
  df['tsignal'].loc[df.tsignal==0] = df.loc[df.tsignal==0]['atsignal']
  # Drop unnecessary features
  df.drop(['atsignal', 'rolling_max_return', 'rolling_min_return', 'ep'] , axis=1, inplace=True)
  # drop nans after replacing infinity
  df.replace([np.inf, -np.inf], np.nan, inplace=True)
  df.dropna(inplace=True)
  return df
# lags value here l = 7, profit/loss = 2
df = sign(df, 7)

# %% [markdown]
# ## 5.2. Plot actual signals

# %%
def plot_signals(df, title, ylabel):
  # Initialize the plot figure
  fig = plt.figure(figsize=(32,16))

  partddf = df[-200:]
  ## Add a subplot and label for y-axis
  axe_predictions = fig.add_subplot(111,ylabel=ylabel)

  ## Plot the closing price
  partddf['IXIC'].plot(ax=axe_predictions, color='#2ECC71', lw=5.)

  # Plot the buy signals
  axe_predictions.plot(partddf.loc[partddf.tsignal == 1.0].index, 
          partddf.IXIC[partddf.tsignal == 1.0],
          '^', markersize=10, color='b')

  # Plot the sell signals
  axe_predictions.plot(partddf.loc[df.tsignal == -1.0].index, 
          partddf.IXIC[df.tsignal == -1.0],
          'v', markersize=10, color='r')
  # Display plt
  axe_predictions.set_title(title)
  plt.show()

# %%
ylabel = 'Nasdaq Composite (IXIC) - Daily'
title = 'IXIC actual signals (Training Dataset)'
plot_signals(df, title, ylabel)

# %% [markdown]
# # 6. Implement Random Forrest Model
# Train, Hyperparameter tuning, performance score, Crossvalidation score

# %%
# Specify features
feature_names = list(df.columns)
non_features = ['tsignal', 'IXIC', 'VIX', 'SPX', 'M1', 'M2', 'M3', 'ixic_hist', 'spx_hist', 'vix_hist'] 
for nf in non_features:
  feature_names.remove(nf)
print(feature_names)
# Out:
# ['contango_m1', 'contango_m2', 'contango_m3', 'vix_macd', 'vix_signal', 'spx_macd', 'spx_signal', 'ixic_macd', 'ixic_signal']

# %%
# train the RFC model
X = df[feature_names]
y = df['tsignal']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

rfc = RandomForestClassifier(random_state=100)

rfc = rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
report = classification_report(y_test, y_pred)
print('Model accuracy', accuracy_score(y_test, y_pred, normalize=True))
print ('Cross Val score', np.mean(cross_val_score(rfc, X_train, y_train, cv=10)))
print(report)
# Out:
# Model accuracy 0.7066666666666667
# Cross Val score 0.7022829131652661
#               precision    recall  f1-score   support
#
#           -1       0.72      0.62      0.67        95
#            0       0.39      0.21      0.28        42
#            1       0.74      0.88      0.80       163
#
#     accuracy                           0.71       300
#    macro avg       0.62      0.57      0.58       300
# weighted avg       0.68      0.71      0.69       300

# %% [markdown]
# ## 6.1. Hyperparameter tuning GridSearchCV (Optional)
# Takes time

# %%
"""
param_dict = {
    "criterion": ['gini', 'entropy'],
    "max_depth": range(1, 10),
    "min_samples_split": range(1, 10),
    "min_samples_leaf": range(1, 10)
}

grid = GridSearchCV(rfc, 
                    param_grid=param_dict,
                    cv = 3,
                    verbose = 1,
                    n_jobs = -1,
                    return_train_score=True)

grid.fit(X_train, y_train)
grid.best_estimator_
"""
# Out:
# '\nparam_dict = {\n    "criterion": [\'gini\', \'entropy\'],\n    "max_depth": range(1, 10),\n    "min_samples_split": range(1, 10),\n    "min_samples_leaf": range(1, 10)\n}\n\ngrid = GridSearchCV(rfc, \n                    param_grid=param_dict,\n                    cv = 3,\n                    verbose = 1,\n                    n_jobs = -1,\n                    return_train_score=True)\n\ngrid.fit(X_train, y_train)\ngrid.best_estimator_\n'

# %% [markdown]
# ## 6.2. Model feature importance
# The mean decrease in Gini coefficient is a measure of how each variable contributes to the homogeneity of the nodes and leaves in the resulting random forest. The higher the value of mean decrease accuracy or mean decrease Gini score, the higher the importance of the variable in the model.

# %%
importances = rfc.feature_importances_
forest_importances = pd.Series(importances, index=feature_names)
std = np.std([tree.feature_importances_ for tree in rfc.estimators_], axis=0)
fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# ## 6.3. Plot the signals

# %%
ddf = df.drop(non_features, axis=1)
ddf['predicted_signal'] = rfc.predict(ddf) 
ddf['IXIC'] = df['IXIC']
# reduce data (last 100 days)
display_days = 100
short_ddf = ddf[-display_days:]

# %%
# Initialize the plot figure
fig = plt.figure(figsize=(32,16))

## Add a subplot and label for y-axis
axe_predictions = fig.add_subplot(111,ylabel='Nasdaq Composite (IXIC) - Daily')

## Plot the closing price
short_ddf['IXIC'].plot(ax=axe_predictions, color='#2ECC71', lw=5.)

# Plot the buy signals
axe_predictions.plot(short_ddf.loc[short_ddf.predicted_signal == 1.0].index, 
         short_ddf.IXIC[ddf.predicted_signal == 1.0],
         '^', markersize=10, color='b')

# Plot the sell signals
axe_predictions.plot(short_ddf.loc[short_ddf.predicted_signal == -1.0].index, 
         short_ddf.IXIC[ddf.predicted_signal == -1.0],
         'v', markersize=10, color='r')
# Display plt
axe_predictions.set_title('IXIC movement predictions using Random Decision Trees Model ({last_days} Days)'.format(last_days=display_days))
plt.show()

# %% [markdown]
# ##6.4. Predictions in Contango vs Backwardation

# %%
signalDf = pd.DataFrame({'actual_signal':df['tsignal'] , 'predicted_signal':ddf['predicted_signal'], 'contango_m1': df['contango_m1']})
# take only test Data
contango = signalDf.loc[signalDf['contango_m1']>0]
backwardation = signalDf.loc[signalDf['contango_m1']<0]
print('Total signals: ', len(signalDf))
print('Contango Count:', len(contango))
print('Backwardation Count:', len(backwardation))
print('Accuracy in Contango (M1)', len(contango.loc[contango['predicted_signal'] == contango['actual_signal']])/len(contango))
print('Accuracy in Backwardation (M1)', len(backwardation.loc[backwardation['predicted_signal'] == backwardation['actual_signal']])/len(backwardation))
# Out:
# Total signals:  1499
# Contango Count: 1189
# Backwardation Count: 306
# Accuracy in Contango (M1) 0.9486963835155593
# Accuracy in Backwardation (M1) 0.9117647058823529

# %% [markdown]
# ## 6.5. Confusion Matrix
# Express how many of a classifier’s predictions were correct, and when incorrect, where the classifier got confused

# %%
# Get and reshape confusion matrix data
matrix = confusion_matrix(y_test, y_pred)
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]

# Build the plot
plt.figure(figsize=(16,7))
sns.set(font_scale=1.4)
sns.heatmap(matrix, annot=True, annot_kws={'size':10},
            cmap=plt.cm.Greens, linewidths=0.2)

# Add labels to the plot
class_names = ['-1 (Short)', '0 (No trade)', '1 (Long)']
tick_marks = np.arange(len(class_names))
tick_marks2 = tick_marks + 0.5
plt.xticks(tick_marks, class_names, rotation=25)
plt.yticks(tick_marks2, class_names, rotation=0)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix for Random Forest Model')
plt.show()

# %% [markdown]
# We can see that our model struggles in predicting 'no trade' signal, which is not very important since we are focusing only on Long and Short signals.

# %% [markdown]
# # 7. Backtesting
# ## 7.1. Backtesting using Backtrader

# %%
# %matplotlib inline
import backtrader as bt
import pyfolio as pf
from backtrader.feeds import PandasData
# download ticker ‘Adj Close’ price from yahoo finance
ticker = '^IXIC'
prices = yf.download(ticker, progress=True, actions=True,start=start_date, end=end_date)
stock =  prices['Adj Close']
stock = pd.DataFrame(stock)
# calculate daily log returns and market direction
stock['returns'] = np.log(stock / stock.shift(1))
stock.dropna(inplace=True)
stock['direction'] = np.sign(stock['returns']).astype(int)
# rename the columns as needed for Backtrader
prices.drop(['Close', 'Dividends', 'Stock Splits'], inplace=True, axis=1)
prices.rename(columns = {'Open':'open','High':'high','Low':'low','Adj Close':'close','Volume':'volume',
                         }, inplace=True)
# predictions
predictions = ddf.predicted_signal
predictions = pd.DataFrame(predictions)
predictions.rename(columns = {'predicted_signal':'predicted'}, inplace=True)
prices = predictions.join(prices, how='right').dropna()
prices.tail(2)
# Out:
# [*********************100%***********************]  1 of 1 completed
#             predicted          open          high           low         close  \
# Date
# 2022-04-06        1.0  14002.580078  14032.839844  13788.900391  13888.820312
# 2022-04-07        0.0  13861.490234  13978.250000  13689.230469  13897.299805
#
#                 volume
# Date
# 2022-04-06  5265740000
# 2022-04-07  4822420000

# %%
OHLCV = ['open', 'high', 'low', 'close', 'volume']
# class to define the columns we will provide
class SignalData(PandasData):
    """
    Define pandas DataFrame structure
    """
    cols = OHLCV + ['predicted']
# create lines
    lines = tuple(cols)
# define parameters
    params = {c: -1 for c in cols}
    params.update({'datetime': None})
    params = tuple(params.items())

# %%
class RFCStrategy(bt.Strategy):
    params = dict(
       # put parameters here (refer to the documentation) 
    )

    def __init__(self):
        self.data_predicted = self.datas[0].predicted  # This is the predicted value of our RFC
        self.data_close = self.datas[0].Close # Adjusted Close Price
        self.data_open = self.datas[0].Open
        # buy price/buy commission
        self.order = None
        self.price = None
        self.comm = None
    # logging function
    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return
        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f},Commission: {order.executed.comm:.2f}'
                )
                self.price = order.executed.price
                self.comm = order.executed.comm
            else:
                self.log(f'SELL EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f},Commission: {order.executed.comm:.2f}'
                )
        # report failed order
        elif order.status in [order.Canceled, order.Margin, 
                              order.Rejected]:
            self.log('Order Failed')
        # set no pending order
        self.order = None
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'OPERATION RESULT --- Gross: {trade.pnl:.2f}, Net: {trade.pnlcomm:.2f}')
    # We have set cheat_on_open = True.This means that we calculated the signals on day t's close price, 
    # but calculated the number of shares we wanted to buy based on day t+1's open price.
    def next_open(self):
        if not self.position:
            if self.data_predicted > 0:
                # calculate the max number of shares ('all-in')
                size = int(self.broker.getcash() / self.datas[0].open)
                # buy order
                self.log(f'BUY CREATED --- Size: {size}, Cash: {self.broker.getcash():.2f}, Open: {self.data_open}, Close: {self.data_close}')
                self.buy(size=size)
        else:
            if self.data_predicted < 0:
                # sell order
                self.log(f'SELL CREATED --- Size: {self.position.size}')
                self.sell(size=self.position.size)

# %%
# instantiate SignalData class
data = SignalData(dataname=prices)
# instantiate Cerebro, add strategy, data, initial cash, commission and pyfolio for performance analysis
cerebro = bt.Cerebro(stdstats = False, cheat_on_open=True)
cerebro.addstrategy(RFCStrategy)
cerebro.adddata(data, name= '^IXIC')
cerebro.broker.setcash(100000.0)
cerebro.broker.setcommission(commission=0.001)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
# run the backtest
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
backtest_result = cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2016-05-04, BUY CREATED --- Size: 21, Cash: 100000.00, Open: 3, Close: 0
# 2016-05-04, BUY EXECUTED --- Price: 4735.28, Cost: 99440.88,Commission: 99.44
# 2016-05-10, SELL CREATED --- Size: 21
# 2016-05-10, SELL EXECUTED --- Price: 4768.91, Cost: 99440.88,Commission: 100.15
# 2016-05-10, OPERATION RESULT --- Gross: 706.24, Net: 506.65
# 2016-05-12, BUY CREATED --- Size: 21, Cash: 100506.65, Open: 3, Close: 0
# 2016-05-12, BUY EXECUTED --- Price: 4778.19, Cost: 100341.99,Commission: 100.34
# 2016-06-01, SELL CREATED --- Size: 21
# 2016-06-01, SELL EXECUTED --- Price: 4928.97, Cost: 100341.99,Commission: 103.51
# 2016-06-01, OPERATION RESULT --- Gross: 3166.39, Net: 2962.54
# 2016-06-14, BUY CREATED --- Size: 21, Cash: 103469.19, Open: 3, Close: 0
# 2016-06-14, BUY EXECUTED --- Price: 4836.67, Cost: 101570.07,Commission: 101.57
# 2016-06-15, SELL CREATED --- Size: 21
# 2016-06-15, SELL EXECUTED --- Price: 4855.08, Cost: 101570.07,Commission: 101.96
# 2016-06-15, OPERATION RESULT --- Gross: 386.61, Net: 183.09
# 2016-06-22, BUY CREATED --- Size: 21, Cash: 103652.27, Open: 3, Close: 0
# 2016-06-22, BUY EXECUTED --- Price: 4846.68, Cost: 101780.28,Commission: 101.78
# 2016-07-13, SELL CREATED --- Size: 21
# 2016-07-13, SELL EXECUTED --- Price: 5036.32, Cost: 101780.28,Commission: 105.76
# 2016-07-13, OPERATION RESULT --- Gross: 3982.43, Net: 3774.89
# 2016-07-14, BUY CREATED --- Size: 21, Cash: 107427.16, Open: 3, Close: 0
# 2016-07-14, BUY EXECUTED --- Price: 5041.95, Cost: 105880.95,Commission: 105.88
# 2016-08-15, SELL CREATED --- Size: 21
# 2016-08-15, SELL EXECUTED --- Price: 5242.18, Cost: 105880.95,Commission: 110.09
# 2016-08-15, OPERATION RESULT --- Gross: 4204.83, Net: 3988.86
# 2016-08-16, BUY CREATED --- Size: 21, Cash: 111416.02, Open: 3, Close: 0
# 2016-08-16, BUY EXECUTED --- Price: 5247.96, Cost: 110207.16,Commission: 110.21
# 2016-08-22, SELL CREATED --- Size: 21
# 2016-08-22, SELL EXECUTED --- Price: 5231.46, Cost: 110207.16,Commission: 109.86
# 2016-08-22, OPERATION RESULT --- Gross: -346.50, Net: -566.57
# 2016-08-24, BUY CREATED --- Size: 21, Cash: 110849.46, Open: 3, Close: 0
# 2016-08-24, BUY EXECUTED --- Price: 5254.42, Cost: 110342.82,Commission: 110.34
# 2016-08-30, SELL CREATED --- Size: 21
# 2016-08-30, SELL EXECUTED --- Price: 5229.88, Cost: 110342.82,Commission: 109.83
# 2016-08-30, OPERATION RESULT --- Gross: -515.34, Net: -735.51
# 2016-09-09, BUY CREATED --- Size: 21, Cash: 110113.95, Open: 3, Close: 0
# 2016-09-09, BUY EXECUTED --- Price: 5217.95, Cost: 109576.95,Commission: 109.58
# 2016-09-22, SELL CREATED --- Size: 21
# 2016-09-22, SELL EXECUTED --- Price: 5323.26, Cost: 109576.95,Commission: 111.79
# 2016-09-22, OPERATION RESULT --- Gross: 2211.50, Net: 1990.14
# 2016-09-26, BUY CREATED --- Size: 21, Cash: 112104.08, Open: 3, Close: 0
# 2016-09-26, BUY EXECUTED --- Price: 5275.73, Cost: 110790.33,Commission: 110.79
# 2016-09-27, SELL CREATED --- Size: 21
# 2016-09-27, SELL EXECUTED --- Price: 5254.18, Cost: 110790.33,Commission: 110.34
# 2016-09-27, OPERATION RESULT --- Gross: -452.55, Net: -673.67
# 2016-09-29, BUY CREATED --- Size: 20, Cash: 111430.41, Open: 3, Close: 0
# 2016-09-29, BUY EXECUTED --- Price: 5311.31, Cost: 106226.20,Commission: 106.23
# 2016-09-30, SELL CREATED --- Size: 20
# 2016-09-30, SELL EXECUTED --- Price: 5288.87, Cost: 106226.20,Commission: 105.78
# 2016-09-30, OPERATION RESULT --- Gross: -448.80, Net: -660.80
# 2016-10-13, BUY CREATED --- Size: 21, Cash: 110769.60, Open: 3, Close: 0
# 2016-10-13, BUY EXECUTED --- Price: 5200.30, Cost: 109206.30,Commission: 109.21
# 2016-10-24, SELL CREATED --- Size: 21
# 2016-10-24, SELL EXECUTED --- Price: 5290.31, Cost: 109206.30,Commission: 111.10
# 2016-10-24, OPERATION RESULT --- Gross: 1890.22, Net: 1669.91
# 2016-11-02, BUY CREATED --- Size: 21, Cash: 112439.52, Open: 3, Close: 0
# 2016-11-02, BUY EXECUTED --- Price: 5147.28, Cost: 108092.88,Commission: 108.09
# 2016-11-21, SELL CREATED --- Size: 21
# 2016-11-21, SELL EXECUTED --- Price: 5336.78, Cost: 108092.88,Commission: 112.07
# 2016-11-21, OPERATION RESULT --- Gross: 3979.50, Net: 3759.33
# 2016-12-01, BUY CREATED --- Size: 21, Cash: 116198.85, Open: 3, Close: 0
# 2016-12-01, BUY EXECUTED --- Price: 5323.88, Cost: 111801.48,Commission: 111.80
# 2016-12-20, SELL CREATED --- Size: 21
# 2016-12-20, SELL EXECUTED --- Price: 5473.53, Cost: 111801.48,Commission: 114.94
# 2016-12-20, OPERATION RESULT --- Gross: 3142.65, Net: 2915.90
# 2016-12-28, BUY CREATED --- Size: 21, Cash: 119114.75, Open: 3, Close: 0
# 2016-12-28, BUY EXECUTED --- Price: 5497.44, Cost: 115446.24,Commission: 115.45
# 2017-01-11, SELL CREATED --- Size: 21
# 2017-01-11, SELL EXECUTED --- Price: 5550.72, Cost: 115446.24,Commission: 116.57
# 2017-01-11, OPERATION RESULT --- Gross: 1118.89, Net: 886.87
# 2017-01-12, BUY CREATED --- Size: 21, Cash: 120001.63, Open: 3, Close: 0
# 2017-01-12, BUY EXECUTED --- Price: 5542.56, Cost: 116393.76,Commission: 116.39
# 2017-01-25, SELL CREATED --- Size: 21
# 2017-01-25, SELL EXECUTED --- Price: 5635.86, Cost: 116393.76,Commission: 118.35
# 2017-01-25, OPERATION RESULT --- Gross: 1959.30, Net: 1724.55
# 2017-01-26, BUY CREATED --- Size: 21, Cash: 121726.18, Open: 3, Close: 0
# 2017-01-26, BUY EXECUTED --- Price: 5666.28, Cost: 118991.88,Commission: 118.99
# 2017-01-27, SELL CREATED --- Size: 21
# 2017-01-27, SELL EXECUTED --- Price: 5664.88, Cost: 118991.88,Commission: 118.96
# 2017-01-27, OPERATION RESULT --- Gross: -29.40, Net: -267.35
# 2017-01-30, BUY CREATED --- Size: 21, Cash: 121458.83, Open: 3, Close: 0
# 2017-01-30, BUY EXECUTED --- Price: 5635.86, Cost: 118353.06,Commission: 118.35
# 2017-03-01, SELL CREATED --- Size: 21
# 2017-03-01, SELL EXECUTED --- Price: 5874.86, Cost: 118353.06,Commission: 123.37
# 2017-03-01, OPERATION RESULT --- Gross: 5019.00, Net: 4777.27
# 2017-03-06, BUY CREATED --- Size: 21, Cash: 126236.10, Open: 3, Close: 0
# 2017-03-06, BUY EXECUTED --- Price: 5846.42, Cost: 122774.82,Commission: 122.77
# 2017-03-10, SELL CREATED --- Size: 21
# 2017-03-10, SELL EXECUTED --- Price: 5867.16, Cost: 122774.82,Commission: 123.21
# 2017-03-10, OPERATION RESULT --- Gross: 435.54, Net: 189.56
# 2017-03-21, BUY CREATED --- Size: 21, Cash: 126425.66, Open: 3, Close: 0
# 2017-03-21, BUY EXECUTED --- Price: 5923.42, Cost: 124391.82,Commission: 124.39
# 2017-03-29, SELL CREATED --- Size: 21
# 2017-03-29, SELL EXECUTED --- Price: 5875.35, Cost: 124391.82,Commission: 123.38
# 2017-03-29, OPERATION RESULT --- Gross: -1009.47, Net: -1257.24
# 2017-04-12, BUY CREATED --- Size: 21, Cash: 125168.42, Open: 3, Close: 0
# 2017-04-12, BUY EXECUTED --- Price: 5863.59, Cost: 123135.39,Commission: 123.14
# 2017-05-09, SELL CREATED --- Size: 21
# 2017-05-09, SELL EXECUTED --- Price: 6111.82, Cost: 123135.39,Commission: 128.35
# 2017-05-09, OPERATION RESULT --- Gross: 5212.83, Net: 4961.35
# 2017-05-17, BUY CREATED --- Size: 21, Cash: 130129.77, Open: 3, Close: 0
# 2017-05-17, BUY EXECUTED --- Price: 6108.62, Cost: 128281.02,Commission: 128.28
# 2017-06-02, SELL CREATED --- Size: 21
# 2017-06-02, SELL EXECUTED --- Price: 6261.59, Cost: 128281.02,Commission: 131.49
# 2017-06-02, OPERATION RESULT --- Gross: 3212.36, Net: 2952.59
# 2017-06-12, BUY CREATED --- Size: 21, Cash: 133082.36, Open: 3, Close: 0
# 2017-06-12, BUY EXECUTED --- Price: 6153.56, Cost: 129224.76,Commission: 129.22
# 2017-06-13, SELL CREATED --- Size: 21
# 2017-06-13, SELL EXECUTED --- Price: 6206.12, Cost: 129224.76,Commission: 130.33
# 2017-06-13, OPERATION RESULT --- Gross: 1103.76, Net: 844.21
# 2017-06-14, BUY CREATED --- Size: 21, Cash: 133926.56, Open: 3, Close: 0
# 2017-06-14, BUY EXECUTED --- Price: 6237.46, Cost: 130986.66,Commission: 130.99
# 2017-06-21, SELL CREATED --- Size: 21
# 2017-06-21, SELL EXECUTED --- Price: 6202.75, Cost: 130986.66,Commission: 130.26
# 2017-06-21, OPERATION RESULT --- Gross: -728.91, Net: -990.15
# 2017-06-27, BUY CREATED --- Size: 21, Cash: 132936.41, Open: 3, Close: 0
# 2017-06-27, BUY EXECUTED --- Price: 6227.90, Cost: 130785.90,Commission: 130.79
# 2017-06-28, SELL CREATED --- Size: 21
# 2017-06-28, SELL EXECUTED --- Price: 6173.10, Cost: 130785.90,Commission: 129.64
# 2017-06-28, OPERATION RESULT --- Gross: -1150.80, Net: -1411.22
# 2017-06-30, BUY CREATED --- Size: 21, Cash: 131525.19, Open: 3, Close: 0
# 2017-06-30, BUY EXECUTED --- Price: 6166.84, Cost: 129503.64,Commission: 129.50
# 2017-07-24, SELL CREATED --- Size: 21
# 2017-07-24, SELL EXECUTED --- Price: 6387.82, Cost: 129503.64,Commission: 134.14
# 2017-07-24, OPERATION RESULT --- Gross: 4640.58, Net: 4376.93
# 2017-07-31, BUY CREATED --- Size: 21, Cash: 135902.12, Open: 3, Close: 0
# 2017-07-31, BUY EXECUTED --- Price: 6394.69, Cost: 134288.49,Commission: 134.29
# 2017-08-02, SELL CREATED --- Size: 21
# 2017-08-02, SELL EXECUTED --- Price: 6393.10, Cost: 134288.49,Commission: 134.26
# 2017-08-02, OPERATION RESULT --- Gross: -33.39, Net: -301.93
# 2017-08-10, BUY CREATED --- Size: 21, Cash: 135600.19, Open: 3, Close: 0
# 2017-08-10, BUY EXECUTED --- Price: 6312.65, Cost: 132565.65,Commission: 132.57
# 2017-08-14, SELL CREATED --- Size: 21
# 2017-08-14, SELL EXECUTED --- Price: 6306.11, Cost: 132565.65,Commission: 132.43
# 2017-08-14, OPERATION RESULT --- Gross: -137.34, Net: -402.33
# 2017-08-17, BUY CREATED --- Size: 21, Cash: 135197.86, Open: 3, Close: 0
# 2017-08-17, BUY EXECUTED --- Price: 6322.72, Cost: 132777.12,Commission: 132.78
# 2017-08-31, SELL CREATED --- Size: 21
# 2017-08-31, SELL EXECUTED --- Price: 6385.80, Cost: 132777.12,Commission: 134.10
# 2017-08-31, OPERATION RESULT --- Gross: 1324.67, Net: 1057.79
# 2017-09-05, BUY CREATED --- Size: 21, Cash: 136255.65, Open: 3, Close: 0
# 2017-09-05, BUY EXECUTED --- Price: 6414.82, Cost: 134711.22,Commission: 134.71
# 2017-09-12, SELL CREATED --- Size: 21
# 2017-09-12, SELL EXECUTED --- Price: 6448.81, Cost: 134711.22,Commission: 135.43
# 2017-09-12, OPERATION RESULT --- Gross: 713.79, Net: 443.66
# 2017-09-21, BUY CREATED --- Size: 21, Cash: 136699.31, Open: 3, Close: 0
# 2017-09-21, BUY EXECUTED --- Price: 6448.57, Cost: 135419.97,Commission: 135.42
# 2017-10-16, SELL CREATED --- Size: 21
# 2017-10-16, SELL EXECUTED --- Price: 6622.55, Cost: 135419.97,Commission: 139.07
# 2017-10-16, OPERATION RESULT --- Gross: 3653.58, Net: 3379.09
# 2017-10-19, BUY CREATED --- Size: 21, Cash: 140078.40, Open: 3, Close: 0
# 2017-10-19, BUY EXECUTED --- Price: 6583.70, Cost: 138257.70,Commission: 138.26
# 2017-11-06, SELL CREATED --- Size: 21
# 2017-11-06, SELL EXECUTED --- Price: 6763.30, Cost: 138257.70,Commission: 142.03
# 2017-11-06, OPERATION RESULT --- Gross: 3771.59, Net: 3491.30
# 2017-11-10, BUY CREATED --- Size: 21, Cash: 143569.70, Open: 3, Close: 0
# 2017-11-10, BUY EXECUTED --- Price: 6736.39, Cost: 141464.19,Commission: 141.46
# 2017-11-22, SELL CREATED --- Size: 21
# 2017-11-22, SELL EXECUTED --- Price: 6869.53, Cost: 141464.19,Commission: 144.26
# 2017-11-22, OPERATION RESULT --- Gross: 2795.93, Net: 2510.21
# 2017-12-04, BUY CREATED --- Size: 21, Cash: 146079.91, Open: 3, Close: 0
# 2017-12-04, BUY EXECUTED --- Price: 6897.13, Cost: 144839.73,Commission: 144.84
# 2017-12-18, SELL CREATED --- Size: 21
# 2017-12-18, SELL EXECUTED --- Price: 6980.40, Cost: 144839.73,Commission: 146.59
# 2017-12-18, OPERATION RESULT --- Gross: 1748.67, Net: 1457.24
# 2017-12-21, BUY CREATED --- Size: 21, Cash: 147537.15, Open: 3, Close: 0
# 2017-12-21, BUY EXECUTED --- Price: 6972.88, Cost: 146430.48,Commission: 146.43
# 2018-01-25, SELL CREATED --- Size: 21
# 2018-01-25, SELL EXECUTED --- Price: 7457.95, Cost: 146430.48,Commission: 156.62
# 2018-01-25, OPERATION RESULT --- Gross: 10186.48, Net: 9883.43
# 2018-02-08, BUY CREATED --- Size: 22, Cash: 157420.58, Open: 3, Close: 0
# 2018-02-08, BUY EXECUTED --- Price: 7067.30, Cost: 155480.60,Commission: 155.48
# 2018-02-23, SELL CREATED --- Size: 22
# 2018-02-23, SELL EXECUTED --- Price: 7261.35, Cost: 155480.60,Commission: 159.75
# 2018-02-23, OPERATION RESULT --- Gross: 4269.11, Net: 3953.88
# 2018-02-28, BUY CREATED --- Size: 21, Cash: 161374.46, Open: 3, Close: 0
# 2018-02-28, BUY EXECUTED --- Price: 7371.41, Cost: 154799.61,Commission: 154.80
# 2018-03-09, SELL CREATED --- Size: 21
# 2018-03-09, SELL EXECUTED --- Price: 7475.98, Cost: 154799.61,Commission: 157.00
# 2018-03-09, OPERATION RESULT --- Gross: 2195.97, Net: 1884.17
# 2018-03-28, BUY CREATED --- Size: 23, Cash: 163258.63, Open: 3, Close: 0
# 2018-03-28, BUY EXECUTED --- Price: 6978.30, Cost: 160500.90,Commission: 160.50
# 2018-03-29, SELL CREATED --- Size: 23
# 2018-03-29, SELL EXECUTED --- Price: 6984.66, Cost: 160500.90,Commission: 160.65
# 2018-03-29, OPERATION RESULT --- Gross: 146.29, Net: -174.86
# 2018-04-02, BUY CREATED --- Size: 23, Cash: 163083.77, Open: 3, Close: 0
# 2018-04-02, BUY EXECUTED --- Price: 7016.17, Cost: 161371.91,Commission: 161.37
# 2018-04-17, SELL CREATED --- Size: 23
# 2018-04-17, SELL EXECUTED --- Price: 7215.12, Cost: 161371.91,Commission: 165.95
# 2018-04-17, OPERATION RESULT --- Gross: 4575.85, Net: 4248.53
# 2018-04-24, BUY CREATED --- Size: 23, Cash: 167332.30, Open: 3, Close: 0
# 2018-04-24, BUY EXECUTED --- Price: 7160.77, Cost: 164697.71,Commission: 164.70
# 2018-05-10, SELL CREATED --- Size: 23
# 2018-05-10, SELL EXECUTED --- Price: 7355.90, Cost: 164697.71,Commission: 169.19
# 2018-05-10, OPERATION RESULT --- Gross: 4487.99, Net: 4154.10
# 2018-05-15, BUY CREATED --- Size: 23, Cash: 171486.41, Open: 3, Close: 0
# 2018-05-15, BUY EXECUTED --- Price: 7361.30, Cost: 169309.90,Commission: 169.31
# 2018-06-14, SELL CREATED --- Size: 23
# 2018-06-14, SELL EXECUTED --- Price: 7723.53, Cost: 169309.90,Commission: 177.64
# 2018-06-14, OPERATION RESULT --- Gross: 8331.29, Net: 7984.34
# 2018-06-27, BUY CREATED --- Size: 23, Cash: 179470.75, Open: 3, Close: 0
# 2018-06-27, BUY EXECUTED --- Price: 7586.33, Cost: 174485.59,Commission: 174.49
# 2018-07-18, SELL CREATED --- Size: 23
# 2018-07-18, SELL EXECUTED --- Price: 7859.43, Cost: 174485.59,Commission: 180.77
# 2018-07-18, OPERATION RESULT --- Gross: 6281.30, Net: 5926.05
# 2018-07-30, BUY CREATED --- Size: 23, Cash: 185396.80, Open: 3, Close: 0
# 2018-07-30, BUY EXECUTED --- Price: 7735.27, Cost: 177911.21,Commission: 177.91
# 2018-08-06, SELL CREATED --- Size: 23
# 2018-08-06, SELL EXECUTED --- Price: 7809.54, Cost: 177911.21,Commission: 179.62
# 2018-08-06, OPERATION RESULT --- Gross: 1708.21, Net: 1350.68
# 2018-08-15, BUY CREATED --- Size: 23, Cash: 186747.48, Open: 3, Close: 0
# 2018-08-15, BUY EXECUTED --- Price: 7810.02, Cost: 179630.46,Commission: 179.63
# 2018-08-28, SELL CREATED --- Size: 23
# 2018-08-28, SELL EXECUTED --- Price: 8039.01, Cost: 179630.46,Commission: 184.90
# 2018-08-28, OPERATION RESULT --- Gross: 5266.76, Net: 4902.24
# 2018-09-06, BUY CREATED --- Size: 23, Cash: 191649.71, Open: 3, Close: 0
# 2018-09-06, BUY EXECUTED --- Price: 7998.27, Cost: 183960.21,Commission: 183.96
# 2018-09-13, SELL CREATED --- Size: 23
# 2018-09-13, SELL EXECUTED --- Price: 7999.93, Cost: 183960.21,Commission: 184.00
# 2018-09-13, OPERATION RESULT --- Gross: 38.18, Net: -329.78
# 2018-09-17, BUY CREATED --- Size: 23, Cash: 191319.94, Open: 3, Close: 0
# 2018-09-17, BUY EXECUTED --- Price: 7992.21, Cost: 183820.83,Commission: 183.82
# 2018-09-20, SELL CREATED --- Size: 23
# 2018-09-20, SELL EXECUTED --- Price: 7993.53, Cost: 183820.83,Commission: 183.85
# 2018-09-20, OPERATION RESULT --- Gross: 30.36, Net: -337.32
# 2018-09-21, BUY CREATED --- Size: 23, Cash: 190982.62, Open: 3, Close: 0
# 2018-09-21, BUY EXECUTED --- Price: 8041.69, Cost: 184958.87,Commission: 184.96
# 2018-09-25, SELL CREATED --- Size: 23
# 2018-09-25, SELL EXECUTED --- Price: 8001.59, Cost: 184958.87,Commission: 184.04
# 2018-09-25, OPERATION RESULT --- Gross: -922.30, Net: -1291.30
# 2018-10-10, BUY CREATED --- Size: 24, Cash: 189691.32, Open: 3, Close: 0
# 2018-10-10, BUY EXECUTED --- Price: 7694.08, Cost: 184657.92,Commission: 184.66
# 2018-10-16, SELL CREATED --- Size: 24
# 2018-10-16, SELL EXECUTED --- Price: 7501.78, Cost: 184657.92,Commission: 180.04
# 2018-10-16, OPERATION RESULT --- Gross: -4615.21, Net: -4979.91
# 2018-10-24, BUY CREATED --- Size: 24, Cash: 184711.42, Open: 3, Close: 0
# 2018-10-24, BUY EXECUTED --- Price: 7423.21, Cost: 178157.04,Commission: 178.16
# 2018-11-07, SELL CREATED --- Size: 24
# 2018-11-07, SELL EXECUTED --- Price: 7446.09, Cost: 178157.04,Commission: 178.71
# 2018-11-07, OPERATION RESULT --- Gross: 549.12, Net: 192.25
# 2018-11-20, BUY CREATED --- Size: 26, Cash: 184903.67, Open: 3, Close: 0
# 2018-11-20, BUY EXECUTED --- Price: 6867.43, Cost: 178553.18,Commission: 178.55
# 2018-12-03, SELL CREATED --- Size: 26
# 2018-12-03, SELL EXECUTED --- Price: 7486.13, Cost: 178553.18,Commission: 194.64
# 2018-12-03, OPERATION RESULT --- Gross: 16086.19, Net: 15713.00
# 2018-12-24, BUY CREATED --- Size: 31, Cash: 200616.67, Open: 3, Close: 0
# 2018-12-24, BUY EXECUTED --- Price: 6278.49, Cost: 194633.20,Commission: 194.63
# 2019-01-18, SELL CREATED --- Size: 31
# 2019-01-18, SELL EXECUTED --- Price: 7134.10, Cost: 194633.20,Commission: 221.16
# 2019-01-18, OPERATION RESULT --- Gross: 26523.91, Net: 26108.12
# 2019-01-22, BUY CREATED --- Size: 31, Cash: 226724.78, Open: 3, Close: 0
# 2019-01-22, BUY EXECUTED --- Price: 7109.57, Cost: 220396.66,Commission: 220.40
# 2019-02-05, SELL CREATED --- Size: 31
# 2019-02-05, SELL EXECUTED --- Price: 7356.34, Cost: 220396.66,Commission: 228.05
# 2019-02-05, OPERATION RESULT --- Gross: 7649.87, Net: 7201.43
# 2019-02-07, BUY CREATED --- Size: 31, Cash: 233926.21, Open: 3, Close: 0
# 2019-02-07, BUY EXECUTED --- Price: 7316.50, Cost: 226811.50,Commission: 226.81
# 2019-02-26, SELL CREATED --- Size: 31
# 2019-02-26, SELL EXECUTED --- Price: 7535.29, Cost: 226811.50,Commission: 233.59
# 2019-02-26, OPERATION RESULT --- Gross: 6782.49, Net: 6322.09
# 2019-03-06, BUY CREATED --- Size: 31, Cash: 240248.30, Open: 3, Close: 0
# 2019-03-06, BUY EXECUTED --- Price: 7575.38, Cost: 234836.78,Commission: 234.84
# 2019-03-21, SELL CREATED --- Size: 31
# 2019-03-21, SELL EXECUTED --- Price: 7705.43, Cost: 234836.78,Commission: 238.87
# 2019-03-21, OPERATION RESULT --- Gross: 4031.56, Net: 3557.85
# 2019-03-22, BUY CREATED --- Size: 31, Cash: 243806.15, Open: 3, Close: 0
# 2019-03-22, BUY EXECUTED --- Price: 7800.25, Cost: 241807.75,Commission: 241.81
# 2019-04-23, SELL CREATED --- Size: 31
# 2019-04-23, SELL EXECUTED --- Price: 8026.75, Cost: 241807.75,Commission: 248.83
# 2019-04-23, OPERATION RESULT --- Gross: 7021.50, Net: 6530.86
# 2019-04-25, BUY CREATED --- Size: 30, Cash: 250337.01, Open: 3, Close: 0
# 2019-04-25, BUY EXECUTED --- Price: 8150.85, Cost: 244525.50,Commission: 244.53
# 2019-04-26, SELL CREATED --- Size: 30
# 2019-04-26, SELL EXECUTED --- Price: 8100.28, Cost: 244525.50,Commission: 243.01
# 2019-04-26, OPERATION RESULT --- Gross: -1517.11, Net: -2004.64
# 2019-05-03, BUY CREATED --- Size: 30, Cash: 248332.37, Open: 3, Close: 0
# 2019-05-03, BUY EXECUTED --- Price: 8092.88, Cost: 242786.40,Commission: 242.79
# 2019-05-07, SELL CREATED --- Size: 30
# 2019-05-07, SELL EXECUTED --- Price: 8043.52, Cost: 242786.40,Commission: 241.31
# 2019-05-07, OPERATION RESULT --- Gross: -1480.80, Net: -1964.89
# 2019-05-09, BUY CREATED --- Size: 31, Cash: 246367.48, Open: 3, Close: 0
# 2019-05-09, BUY EXECUTED --- Price: 7853.21, Cost: 243449.51,Commission: 243.45
# 2019-05-10, SELL CREATED --- Size: 31
# 2019-05-10, SELL EXECUTED --- Price: 7881.31, Cost: 243449.51,Commission: 244.32
# 2019-05-10, OPERATION RESULT --- Gross: 871.10, Net: 383.33
# 2019-05-13, BUY CREATED --- Size: 31, Cash: 246750.82, Open: 3, Close: 0
# 2019-05-13, BUY EXECUTED --- Price: 7720.07, Cost: 239322.16,Commission: 239.32
# 2019-05-15, SELL CREATED --- Size: 31
# 2019-05-15, SELL EXECUTED --- Price: 7682.80, Cost: 239322.16,Commission: 238.17
# 2019-05-15, OPERATION RESULT --- Gross: -1155.37, Net: -1632.86
# 2019-05-21, BUY CREATED --- Size: 31, Cash: 245117.96, Open: 3, Close: 0
# 2019-05-21, BUY EXECUTED --- Price: 7765.57, Cost: 240732.66,Commission: 240.73
# 2019-05-23, SELL CREATED --- Size: 31
# 2019-05-23, SELL EXECUTED --- Price: 7660.72, Cost: 240732.66,Commission: 237.48
# 2019-05-23, OPERATION RESULT --- Gross: -3250.34, Net: -3728.55
# 2019-06-03, BUY CREATED --- Size: 32, Cash: 241389.40, Open: 3, Close: 0
# 2019-06-03, BUY EXECUTED --- Price: 7441.21, Cost: 238118.72,Commission: 238.12
# 2019-06-20, SELL CREATED --- Size: 32
# 2019-06-20, SELL EXECUTED --- Price: 8087.45, Cost: 238118.72,Commission: 258.80
# 2019-06-20, OPERATION RESULT --- Gross: 20679.69, Net: 20182.77
# 2019-06-21, BUY CREATED --- Size: 32, Cash: 261572.17, Open: 3, Close: 0
# 2019-06-21, BUY EXECUTED --- Price: 8028.69, Cost: 256918.08,Commission: 256.92
# 2019-07-12, SELL CREATED --- Size: 32
# 2019-07-12, SELL EXECUTED --- Price: 8209.20, Cost: 256918.08,Commission: 262.69
# 2019-07-12, OPERATION RESULT --- Gross: 5776.33, Net: 5256.72
# 2019-07-17, BUY CREATED --- Size: 32, Cash: 266828.89, Open: 3, Close: 0
# 2019-07-17, BUY EXECUTED --- Price: 8224.00, Cost: 263168.00,Commission: 263.17
# 2019-07-23, SELL CREATED --- Size: 32
# 2019-07-23, SELL EXECUTED --- Price: 8242.50, Cost: 263168.00,Commission: 263.76
# 2019-07-23, OPERATION RESULT --- Gross: 592.00, Net: 65.07
# 2019-07-29, BUY CREATED --- Size: 32, Cash: 266893.96, Open: 3, Close: 0
# 2019-07-29, BUY EXECUTED --- Price: 8325.10, Cost: 266403.19,Commission: 266.40
# 2019-07-30, SELL CREATED --- Size: 32
# 2019-07-30, SELL EXECUTED --- Price: 8231.77, Cost: 266403.19,Commission: 263.42
# 2019-07-30, OPERATION RESULT --- Gross: -2986.56, Net: -3516.38
# 2019-07-31, BUY CREATED --- Size: 31, Cash: 263377.58, Open: 3, Close: 0
# 2019-07-31, BUY EXECUTED --- Price: 8290.80, Cost: 257014.79,Commission: 257.01
# 2019-08-01, SELL CREATED --- Size: 31
# 2019-08-01, SELL EXECUTED --- Price: 8190.56, Cost: 257014.79,Commission: 253.91
# 2019-08-01, OPERATION RESULT --- Gross: -3107.43, Net: -3618.35
# 2019-08-06, BUY CREATED --- Size: 33, Cash: 259759.23, Open: 3, Close: 0
# 2019-08-06, BUY EXECUTED --- Price: 7804.51, Cost: 257548.82,Commission: 257.55
# 2019-08-08, SELL CREATED --- Size: 33
# 2019-08-08, SELL EXECUTED --- Price: 7921.59, Cost: 257548.82,Commission: 261.41
# 2019-08-08, OPERATION RESULT --- Gross: 3863.64, Net: 3344.68
# 2019-08-12, BUY CREATED --- Size: 33, Cash: 263103.91, Open: 3, Close: 0
# 2019-08-12, BUY EXECUTED --- Price: 7907.49, Cost: 260947.18,Commission: 260.95
# 2019-08-13, SELL CREATED --- Size: 33
# 2019-08-13, SELL EXECUTED --- Price: 7852.37, Cost: 260947.18,Commission: 259.13
# 2019-08-13, OPERATION RESULT --- Gross: -1818.96, Net: -2339.04
# 2019-08-14, BUY CREATED --- Size: 33, Cash: 260764.87, Open: 3, Close: 0
# 2019-08-14, BUY EXECUTED --- Price: 7877.33, Cost: 259951.89,Commission: 259.95
# 2019-08-15, SELL CREATED --- Size: 33
# 2019-08-15, SELL EXECUTED --- Price: 7790.20, Cost: 259951.89,Commission: 257.08
# 2019-08-15, OPERATION RESULT --- Gross: -2875.29, Net: -3392.31
# 2019-08-23, BUY CREATED --- Size: 32, Cash: 257372.55, Open: 3, Close: 0
# 2019-08-23, BUY EXECUTED --- Price: 7943.65, Cost: 254196.80,Commission: 254.20
# 2019-09-12, SELL CREATED --- Size: 32
# 2019-09-12, SELL EXECUTED --- Price: 8206.58, Cost: 254196.80,Commission: 262.61
# 2019-09-12, OPERATION RESULT --- Gross: 8413.77, Net: 7896.96
# 2019-10-02, BUY CREATED --- Size: 33, Cash: 265269.51, Open: 3, Close: 0
# 2019-10-02, BUY EXECUTED --- Price: 7851.13, Cost: 259087.29,Commission: 259.09
# 2019-11-25, SELL CREATED --- Size: 33
# 2019-11-25, SELL EXECUTED --- Price: 8559.65, Cost: 259087.29,Commission: 282.47
# 2019-11-25, OPERATION RESULT --- Gross: 23381.18, Net: 22839.62
# 2019-12-02, BUY CREATED --- Size: 33, Cash: 288109.13, Open: 3, Close: 0
# 2019-12-02, BUY EXECUTED --- Price: 8672.84, Cost: 286203.71,Commission: 286.20
# 2020-01-15, SELL CREATED --- Size: 33
# 2020-01-15, SELL EXECUTED --- Price: 9253.76, Cost: 286203.71,Commission: 305.37
# 2020-01-15, OPERATION RESULT --- Gross: 19170.36, Net: 18578.78
# 2020-01-27, BUY CREATED --- Size: 33, Cash: 306687.91, Open: 3, Close: 0
# 2020-01-27, BUY EXECUTED --- Price: 9092.46, Cost: 300051.18,Commission: 300.05
# 2020-02-12, SELL CREATED --- Size: 33
# 2020-02-12, SELL EXECUTED --- Price: 9688.60, Cost: 300051.18,Commission: 319.72
# 2020-02-12, OPERATION RESULT --- Gross: 19672.61, Net: 19052.83
# 2020-02-27, BUY CREATED --- Size: 37, Cash: 325740.74, Open: 3, Close: 0
# 2020-02-27, BUY EXECUTED --- Price: 8744.03, Cost: 323529.12,Commission: 323.53
# 2020-02-28, SELL CREATED --- Size: 37
# 2020-02-28, SELL EXECUTED --- Price: 8269.74, Cost: 323529.12,Commission: 305.98
# 2020-02-28, OPERATION RESULT --- Gross: -17548.73, Net: -18178.24
# 2020-03-16, BUY CREATED --- Size: 41, Cash: 307562.50, Open: 3, Close: 0
# 2020-03-16, BUY EXECUTED --- Price: 7392.73, Cost: 303101.93,Commission: 303.10
# 2020-05-08, SELL CREATED --- Size: 41
# 2020-05-08, SELL EXECUTED --- Price: 9056.89, Cost: 303101.93,Commission: 371.33
# 2020-05-08, OPERATION RESULT --- Gross: 68230.55, Net: 67556.11
# 2020-05-11, BUY CREATED --- Size: 41, Cash: 375118.62, Open: 3, Close: 0
# 2020-05-11, BUY EXECUTED --- Price: 9054.91, Cost: 371251.32,Commission: 371.25
# 2020-06-08, SELL CREATED --- Size: 41
# 2020-06-08, SELL EXECUTED --- Price: 9823.44, Cost: 371251.32,Commission: 402.76
# 2020-06-08, OPERATION RESULT --- Gross: 31509.74, Net: 30735.73
# 2020-06-12, BUY CREATED --- Size: 41, Cash: 405854.34, Open: 3, Close: 0
# 2020-06-12, BUY EXECUTED --- Price: 9715.87, Cost: 398350.67,Commission: 398.35
# 2020-06-22, SELL CREATED --- Size: 41
# 2020-06-22, SELL EXECUTED --- Price: 9945.49, Cost: 398350.67,Commission: 407.77
# 2020-06-22, OPERATION RESULT --- Gross: 9414.42, Net: 8608.31
# 2020-06-26, BUY CREATED --- Size: 41, Cash: 414462.65, Open: 3, Close: 0
# 2020-06-26, BUY EXECUTED --- Price: 9995.12, Cost: 409799.92,Commission: 409.80
# 2020-07-20, SELL CREATED --- Size: 41
# 2020-07-20, SELL EXECUTED --- Price: 10526.02, Cost: 409799.92,Commission: 431.57
# 2020-07-20, OPERATION RESULT --- Gross: 21766.88, Net: 20925.51
# 2020-07-23, BUY CREATED --- Size: 40, Cash: 435388.16, Open: 3, Close: 0
# 2020-07-23, BUY EXECUTED --- Price: 10689.50, Cost: 427580.00,Commission: 427.58
# 2020-08-05, SELL CREATED --- Size: 40
# 2020-08-05, SELL EXECUTED --- Price: 10967.87, Cost: 427580.00,Commission: 438.71
# 2020-08-05, OPERATION RESULT --- Gross: 11134.80, Net: 10268.51
# 2020-08-06, BUY CREATED --- Size: 40, Cash: 445656.67, Open: 3, Close: 0
# 2020-08-06, BUY EXECUTED --- Price: 10989.98, Cost: 439599.22,Commission: 439.60
# 2020-09-01, SELL CREATED --- Size: 40
# 2020-09-01, SELL EXECUTED --- Price: 11850.96, Cost: 439599.22,Commission: 474.04
# 2020-09-01, OPERATION RESULT --- Gross: 34439.18, Net: 33525.54
# 2020-09-08, BUY CREATED --- Size: 43, Cash: 479182.22, Open: 3, Close: 0
# 2020-09-08, BUY EXECUTED --- Price: 10900.70, Cost: 468730.11,Commission: 468.73
# 2020-09-09, SELL CREATED --- Size: 43
# 2020-09-09, SELL EXECUTED --- Price: 11064.76, Cost: 468730.11,Commission: 475.78
# 2020-09-09, OPERATION RESULT --- Gross: 7054.56, Net: 6110.05
# 2020-09-10, BUY CREATED --- Size: 43, Cash: 485292.26, Open: 3, Close: 0
# 2020-09-10, BUY EXECUTED --- Price: 11235.53, Cost: 483127.80,Commission: 483.13
# 2020-09-11, SELL CREATED --- Size: 43
# 2020-09-11, SELL EXECUTED --- Price: 11010.07, Cost: 483127.80,Commission: 473.43
# 2020-09-11, OPERATION RESULT --- Gross: -9694.78, Net: -10651.34
# 2020-09-23, BUY CREATED --- Size: 43, Cash: 474640.92, Open: 3, Close: 0
# 2020-09-23, BUY EXECUTED --- Price: 10950.82, Cost: 470885.27,Commission: 470.89
# 2020-10-12, SELL CREATED --- Size: 43
# 2020-10-12, SELL EXECUTED --- Price: 11732.33, Cost: 470885.27,Commission: 504.49
# 2020-10-12, OPERATION RESULT --- Gross: 33604.92, Net: 32629.54
# 2020-10-23, BUY CREATED --- Size: 43, Cash: 507270.47, Open: 3, Close: 0
# 2020-10-23, BUY EXECUTED --- Price: 11536.01, Cost: 496048.42,Commission: 496.05
# 2020-10-26, SELL CREATED --- Size: 43
# 2020-10-26, SELL EXECUTED --- Price: 11440.64, Cost: 496048.42,Commission: 491.95
# 2020-10-26, OPERATION RESULT --- Gross: -4100.92, Net: -5088.91
# 2020-10-30, BUY CREATED --- Size: 45, Cash: 502181.56, Open: 3, Close: 0
# 2020-10-30, BUY EXECUTED --- Price: 11103.47, Cost: 499656.14,Commission: 499.66
# 2020-11-06, SELL CREATED --- Size: 45
# 2020-11-06, SELL EXECUTED --- Price: 11869.90, Cost: 499656.14,Commission: 534.15
# 2020-11-06, OPERATION RESULT --- Gross: 34489.38, Net: 33455.58
# 2020-11-10, BUY CREATED --- Size: 46, Cash: 535637.13, Open: 3, Close: 0
# 2020-11-10, BUY EXECUTED --- Price: 11622.44, Cost: 534632.26,Commission: 534.63
# 2021-01-20, SELL CREATED --- Size: 46
# 2021-01-20, SELL EXECUTED --- Price: 13342.55, Cost: 534632.26,Commission: 613.76
# 2021-01-20, OPERATION RESULT --- Gross: 79125.03, Net: 77976.64
# 2021-01-29, BUY CREATED --- Size: 46, Cash: 613613.78, Open: 3, Close: 0
# 2021-01-29, BUY EXECUTED --- Price: 13284.72, Cost: 611097.11,Commission: 611.10
# 2021-02-08, SELL CREATED --- Size: 46
# 2021-02-08, SELL EXECUTED --- Price: 13937.06, Cost: 611097.11,Commission: 641.10
# 2021-02-08, OPERATION RESULT --- Gross: 30007.63, Net: 28755.43
# 2021-03-01, BUY CREATED --- Size: 47, Cash: 642369.21, Open: 3, Close: 0
# 2021-03-01, BUY EXECUTED --- Price: 13406.16, Cost: 630089.53,Commission: 630.09
# 2021-03-02, SELL CREATED --- Size: 47
# 2021-03-02, SELL EXECUTED --- Price: 13599.45, Cost: 630089.53,Commission: 639.17
# 2021-03-02, OPERATION RESULT --- Gross: 9084.63, Net: 7815.37
# 2021-03-04, BUY CREATED --- Size: 50, Cash: 650184.58, Open: 3, Close: 0
# 2021-03-04, BUY EXECUTED --- Price: 12953.99, Cost: 647699.51,Commission: 647.70
# 2021-03-11, SELL CREATED --- Size: 50
# 2021-03-11, SELL EXECUTED --- Price: 13273.31, Cost: 647699.51,Commission: 663.67
# 2021-03-11, OPERATION RESULT --- Gross: 15965.97, Net: 14654.60
# 2021-03-23, BUY CREATED --- Size: 49, Cash: 664839.18, Open: 3, Close: 0
# 2021-03-23, BUY EXECUTED --- Price: 13381.43, Cost: 655690.05,Commission: 655.69
# 2021-04-13, SELL CREATED --- Size: 49
# 2021-04-13, SELL EXECUTED --- Price: 13902.45, Cost: 655690.05,Commission: 681.22
# 2021-04-13, OPERATION RESULT --- Gross: 25530.00, Net: 24193.09
# 2021-04-19, BUY CREATED --- Size: 49, Cash: 689032.27, Open: 3, Close: 0
# 2021-04-19, BUY EXECUTED --- Price: 13984.58, Cost: 685244.42,Commission: 685.24
# 2021-04-23, SELL CREATED --- Size: 49
# 2021-04-23, SELL EXECUTED --- Price: 13861.37, Cost: 685244.42,Commission: 679.21
# 2021-04-23, OPERATION RESULT --- Gross: -6037.29, Net: -7401.74
# 2021-05-12, BUY CREATED --- Size: 51, Cash: 681630.53, Open: 3, Close: 0
# 2021-05-12, BUY EXECUTED --- Price: 13215.49, Cost: 673990.00,Commission: 673.99
# 2021-07-06, SELL CREATED --- Size: 51
# 2021-07-06, SELL EXECUTED --- Price: 14661.55, Cost: 673990.00,Commission: 747.74
# 2021-07-06, OPERATION RESULT --- Gross: 73749.04, Net: 72327.31
# 2021-07-19, BUY CREATED --- Size: 52, Cash: 753957.84, Open: 3, Close: 0
# 2021-07-19, BUY EXECUTED --- Price: 14235.98, Cost: 740270.98,Commission: 740.27
# 2021-07-23, SELL CREATED --- Size: 52
# 2021-07-23, SELL EXECUTED --- Price: 14753.06, Cost: 740270.98,Commission: 767.16
# 2021-07-23, OPERATION RESULT --- Gross: 26888.11, Net: 25380.68
# 2021-07-26, BUY CREATED --- Size: 52, Cash: 779338.52, Open: 3, Close: 0
# 2021-07-26, BUY EXECUTED --- Price: 14821.03, Cost: 770693.57,Commission: 770.69
# 2021-08-09, SELL CREATED --- Size: 52
# 2021-08-09, SELL EXECUTED --- Price: 14855.76, Cost: 770693.57,Commission: 772.50
# 2021-08-09, OPERATION RESULT --- Gross: 1805.93, Net: 262.74
# 2021-08-17, BUY CREATED --- Size: 53, Cash: 779601.26, Open: 3, Close: 0
# 2021-08-17, BUY EXECUTED --- Price: 14670.56, Cost: 777539.66,Commission: 777.54
# 2021-09-01, SELL CREATED --- Size: 53
# 2021-09-01, SELL EXECUTED --- Price: 15308.98, Cost: 777539.66,Commission: 811.38
# 2021-09-01, OPERATION RESULT --- Gross: 33836.31, Net: 32247.39
# 2021-09-14, BUY CREATED --- Size: 53, Cash: 811848.66, Open: 3, Close: 0
# 2021-09-14, BUY EXECUTED --- Price: 15168.45, Cost: 803927.86,Commission: 803.93
# 2021-09-15, SELL CREATED --- Size: 53
# 2021-09-15, SELL EXECUTED --- Price: 15071.34, Cost: 803927.86,Commission: 798.78
# 2021-09-15, OPERATION RESULT --- Gross: -5146.85, Net: -6749.56
# 2021-09-21, BUY CREATED --- Size: 54, Cash: 805099.10, Open: 3, Close: 0
# 2021-09-21, BUY EXECUTED --- Price: 14803.36, Cost: 799381.46,Commission: 799.38
# 2021-09-22, SELL CREATED --- Size: 54
# 2021-09-22, SELL EXECUTED --- Price: 14800.59, Cost: 799381.46,Commission: 799.23
# 2021-09-22, OPERATION RESULT --- Gross: -149.61, Net: -1748.22
# 2021-10-01, BUY CREATED --- Size: 55, Cash: 803350.88, Open: 3, Close: 0
# 2021-10-01, BUY EXECUTED --- Price: 14494.93, Cost: 797221.13,Commission: 797.22
# 2021-11-04, SELL CREATED --- Size: 55
# 2021-11-04, SELL EXECUTED --- Price: 15849.74, Cost: 797221.13,Commission: 871.74
# 2021-11-04, OPERATION RESULT --- Gross: 74514.58, Net: 72845.62
# 2021-11-10, BUY CREATED --- Size: 55, Cash: 876196.50, Open: 3, Close: 0
# 2021-11-10, BUY EXECUTED --- Price: 15753.84, Cost: 866461.19,Commission: 866.46
# 2021-11-12, SELL CREATED --- Size: 55
# 2021-11-12, SELL EXECUTED --- Price: 15752.62, Cost: 866461.19,Commission: 866.39
# 2021-11-12, OPERATION RESULT --- Gross: -67.08, Net: -1799.94
# 2021-11-15, BUY CREATED --- Size: 55, Cash: 874396.56, Open: 3, Close: 0
# 2021-11-15, Order Failed
# 2021-12-01, BUY CREATED --- Size: 55, Cash: 874396.56, Open: 3, Close: 0
# 2021-12-01, BUY EXECUTED --- Price: 15752.27, Cost: 866374.82,Commission: 866.37
# 2021-12-07, SELL CREATED --- Size: 55
# 2021-12-07, SELL EXECUTED --- Price: 15510.91, Cost: 866374.82,Commission: 853.10
# 2021-12-07, OPERATION RESULT --- Gross: -13274.77, Net: -14994.24
# 2021-12-15, BUY CREATED --- Size: 56, Cash: 859402.32, Open: 3, Close: 0
# 2021-12-15, BUY EXECUTED --- Price: 15230.71, Cost: 852919.76,Commission: 852.92
# 2021-12-28, SELL CREATED --- Size: 56
# 2021-12-28, SELL EXECUTED --- Price: 15895.20, Cost: 852919.76,Commission: 890.13
# 2021-12-28, OPERATION RESULT --- Gross: 37211.45, Net: 35468.40
# 2022-01-05, BUY CREATED --- Size: 57, Cash: 894870.72, Open: 3, Close: 0
# 2022-01-05, BUY EXECUTED --- Price: 15547.16, Cost: 886188.13,Commission: 886.19
# 2022-01-11, SELL CREATED --- Size: 57
# 2022-01-11, SELL EXECUTED --- Price: 14919.26, Cost: 886188.13,Commission: 850.40
# 2022-01-11, OPERATION RESULT --- Gross: -35790.32, Net: -37526.91
# 2022-01-26, BUY CREATED --- Size: 61, Cash: 857343.82, Open: 3, Close: 0
# 2022-01-26, BUY EXECUTED --- Price: 13871.77, Cost: 846177.94,Commission: 846.18
# 2022-02-01, SELL CREATED --- Size: 61
# 2022-02-01, SELL EXECUTED --- Price: 14277.43, Cost: 846177.94,Commission: 870.92
# 2022-02-01, OPERATION RESULT --- Gross: 24745.27, Net: 23028.17
# 2022-03-14, BUY CREATED --- Size: 68, Cash: 880371.98, Open: 3, Close: 0
# 2022-03-14, BUY EXECUTED --- Price: 12795.12, Cost: 870068.17,Commission: 870.07
# 2022-03-29, SELL CREATED --- Size: 68
# 2022-03-29, SELL EXECUTED --- Price: 14500.39, Cost: 870068.17,Commission: 986.03
# 2022-03-29, OPERATION RESULT --- Gross: 115958.33, Net: 114102.23
# 2022-04-06, BUY CREATED --- Size: 71, Cash: 994474.22, Open: 3, Close: 0
# 2022-04-06, Order Failed
# Final Portfolio Value: 994474.22

# %% [markdown]
# # 7.2. Performance Analysis of Backtesting
# We will analyze the performance statistics using pyfolio . pyfolio is a Python library for performance and risk analysis of financial portfolios developed by Quantopian Inc.

# %%
# Extract inputs for pyfolio
strat = backtest_result[0]
pyfoliozer = strat.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
returns.name = 'Strategy'
# get benchmark returns
benchmark_rets= stock['returns']
benchmark_rets = benchmark_rets.filter(returns.index)
benchmark_rets.name = 'IXIC'
# get performance statistics for strategy
pf.show_perf_stats(returns)
# plot performance for strategy vs benchmark
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 9),constrained_layout=True)
axes = ax.flatten()
pf.plot_rolling_returns(returns=returns,
                        factor_returns=benchmark_rets,
                        ax=axes[0], title='Cumulative returns vs Initial')
axes[0].grid(True)
pf.plot_drawdown_underwater(returns=returns, ax=axes[1])
axes[1].grid(True)
fig.suptitle('Cumulative Returns vs Drawdowns', fontsize=16, y=0.990)
plt.grid(True)
plt.tight_layout()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-04-27</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-07</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>71</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>47.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>894.5%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.3%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.60</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.81</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.97</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-12.4%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.80</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>4.21</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.46</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>11.39</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.29</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.8%</td>
#     </tr>
#   </tbody>
# </table>
